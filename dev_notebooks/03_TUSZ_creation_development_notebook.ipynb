# %% [markdown]
# # This notebook is for testing adaptated version of the braindecode tuh.py file

# %% [markdown]
# ## Step 1: access the TUH EEG dataset on the rds space

# %%
pwd
# Out:
# '/rds/general/user/nm2318/home/EEG_pipeline'

# %%
file_path_tueeg_example = ('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg/v2.0.0/edf/000/aaaaaaaa/s001_2015_12_30/01_tcp_ar/aaaaaaaa_s001_t000.edf')
TUH_EEG_PATH = ('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg/v2.0.0')

# %%
# sanity check
import mne
raw_tueeg_test = mne.io.read_raw_edf(file_path_tueeg_example)
# Out:
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg/v2.0.0/edf/000/aaaaaaaa/s001_2015_12_30/01_tcp_ar/aaaaaaaa_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %% [markdown]
# ## Step 2: create the class TUEG

# %%
from datasets.tuh import TUH
tuh = TUH(path=TUH_EEG_PATH,    
    recording_ids= None,       
    target_name=('age', 'gender'),  # use both age and gender as decoding target           
    preload=False,    
    debug= True)
# Out:
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg/v2.0.0/edf/068/aaaaakcf/s001_2009_12_23/01_tcp_ar/aaaaakcf_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg/v2.0.0/edf/068/aaaaakel/s001_2010_05_18/01_tcp_ar/aaaaakel_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg/v2.0.0/edf/068/aaaaakbr/s001_2010_07_21/01_tcp_ar/aaaaakbr_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg/v2.0.0/edf/068/aaaaakbs/s001_2010_07_22/02_tcp_le/aaaaakbs_s001_t001.edf...
# EDF file detected
# ...

# %%
tuh.datasets[1].raw.info['ch_names']
# Out:
# ['EEG FP1-REF',
#  'EEG FP2-REF',
#  'EEG F3-REF',
#  'EEG F4-REF',
#  'EEG C3-REF',
#  'EEG C4-REF',
#  'EEG P3-REF',
#  'EEG P4-REF',
#  'EEG O1-REF',
#  'EEG O2-REF',
#  'EEG F7-REF',
#  'EEG F8-REF',
#  'EEG T3-REF',
#  'EEG T4-REF',
#  'EEG T5-REF',
#  'EEG T6-REF',
#  'EEG A1-REF',
#  'EEG A2-REF',
#  'EEG FZ-REF',
#  'EEG CZ-REF',
#  'EEG PZ-REF',
#  'EEG ROC-REF',
#  'EEG LOC-REF',
#  'EEG EKG1-REF',
#  'EMG-REF',
#  'EEG 26-REF',
#  'EEG 27-REF',
#  'EEG 28-REF',
#  'EEG 29-REF',
#  'EEG 30-REF',
#  'EEG T1-REF',
#  'EEG T2-REF',
#  'PHOTIC-REF',
#  'IBI',
#  'BURSTS',
#  'SUPPR']

# %%
tuh.description
# Out:
#     year  month  day                                               path  \
# 0   2009     12   23  /rds/general/user/nm2318/home/projects/scott_d...
# 1   2010      5   18  /rds/general/user/nm2318/home/projects/scott_d...
# 2   2010      7   21  /rds/general/user/nm2318/home/projects/scott_d...
# 3   2010      7   22  /rds/general/user/nm2318/home/projects/scott_d...
# 4   2010      7   22  /rds/general/user/nm2318/home/projects/scott_d...
# ..   ...    ...  ...                                                ...
# 95  2015      9    1  /rds/general/user/nm2318/home/projects/scott_d...
# 96  2015      9    1  /rds/general/user/nm2318/home/projects/scott_d...
# 97  2015      9    1  /rds/general/user/nm2318/home/projects/scott_d...
# 98  2016      1   13  /rds/general/user/nm2318/home/projects/scott_d...
# 99  2016      1   13  /rds/general/user/nm2318/home/projects/scott_d...
#
#    version   subject  session  segment channel_config  age gender
# ...

# %%
tuh.datasets

# %%
tuh.datasets[0].raw.info
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: EEG FP1-REF, EEG FP2-REF, EEG F3-REF, EEG F4-REF, EEG C3-REF, ...
#  chs: 36 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: 2009-12-23 09:41:36 UTC
#  nchan: 36
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: 3 items (dict)
# >

# %%
tuh.datasets[0].raw.annotations
# Out:
# <Annotations | 0 segments>

# %%
tuh.description['path'][0]
# Out:
# '/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg/v2.0.0/edf/068/aaaaakcf/s001_2009_12_23/01_tcp_ar/aaaaakcf_s001_t000.edf'

# %% [markdown]
# ## Optional step: this is to delete any text files created by the read_date function

# %%
date_paths = [file.replace('.edf', '_date.txt') for file in tuh.description['path']]
#date_paths = [file.replace('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg/v2.0.0/edf/068/', '') for file in date_paths]

# %%
cd /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg/v2.0.0/edf/068

# %%
import os
for paths in date_paths:
    os.remove(paths)

# %% [markdown]
# ## Step 3: create TUAB class

# %%
TUH_AB_PATH = ('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_abnormal/v3.0.0')

# %%
from datasets.tuh import TUHAbnormal
tuh_ab = TUHAbnormal(path=TUH_AB_PATH,    
    recording_ids= None,       
    target_name=('pathological'),  # use both age and gender as decoding target           
    preload=False,    
    debug= True)

# %%
len(tuh_ab.datasets)
# Out:
# 100

# %%
tuh_ab.description
# Out:
#     year  month  day                                               path  \
# 0   1899     12   30  /rds/general/user/nm2318/home/projects/scott_d...
# 1   2010      1   19  /rds/general/user/nm2318/home/projects/scott_d...
# 2   2010      2   12  /rds/general/user/nm2318/home/projects/scott_d...
# 3   2010      2   22  /rds/general/user/nm2318/home/projects/scott_d...
# 4   2010      3    1  /rds/general/user/nm2318/home/projects/scott_d...
# ..   ...    ...  ...                                                ...
# 95  2013      7   21  /rds/general/user/nm2318/home/projects/scott_d...
# 96  2013      8   14  /rds/general/user/nm2318/home/projects/scott_d...
# 97  2013      8   16  /rds/general/user/nm2318/home/projects/scott_d...
# 98  2013      8   16  /rds/general/user/nm2318/home/projects/scott_d...
# 99  2013      8   30  /rds/general/user/nm2318/home/projects/scott_d...
#
#      subject  session  segment  age gender version    set  pathological  \
# ...

# %% [markdown]
# ## Step 4: try to create a class for TUSZ

# %%
TUH_SZ_PATH = ('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0')

# %%
from datasets.tuh import TUHSeizure
tuh_sz = TUHSeizure(path=TUH_SZ_PATH,    
    recording_ids= None,       
    target_name=None,    
    preload=True,    
    debug= True)
# Out:
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaexe/s001_2006_10_11/02_tcp_le/aaaaaexe_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 356499  =      0.000 ...  1425.996 secs...
# OrderedDict([('onset', 193.844), ('duration', 6.200000000000017), ('description', 'absz,1.0,EVENT'), ('orig_time', None), ('ch_names', ('FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'A1-T3', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'T4-A2', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2'))])
#
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaoec/s001_2012_11_05/01_tcp_ar/aaaaaoec_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# ...

# %%
tuh_sz.datasets[1].raw.annotations
# Out:
# <Annotations | 3 segments: seiz,1.0,TERM (3)>

# %%
tuh_sz.datasets[1].description['path']
# Out:
# '/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaoec/s001_2012_11_05/01_tcp_ar/aaaaaoec_s001_t000.edf'

# %%
tuh_sz.datasets[1].raw.info['ch_names']
# Out:
# ['EEG FP1-REF',
#  'EEG FP2-REF',
#  'EEG F3-REF',
#  'EEG F4-REF',
#  'EEG C3-REF',
#  'EEG C4-REF',
#  'EEG P3-REF',
#  'EEG P4-REF',
#  'EEG O1-REF',
#  'EEG O2-REF',
#  'EEG F7-REF',
#  'EEG F8-REF',
#  'EEG T3-REF',
#  'EEG T4-REF',
#  'EEG T5-REF',
#  'EEG T6-REF',
#  'EEG A1-REF',
#  'EEG A2-REF',
#  'EEG FZ-REF',
#  'EEG CZ-REF',
#  'EEG PZ-REF',
#  'EEG ROC-REF',
#  'EEG LOC-REF',
#  'EEG EKG1-REF',
#  'EEG T1-REF',
#  'EEG T2-REF',
#  'PHOTIC-REF',
#  'IBI',
#  'BURSTS',
#  'SUPPR']

# %%
import mne
tuh_sz.datasets[0].raw.get_montage()
mne.channels.get_builtin_montages()
tuh_sz.datasets[0].raw.set_montage(montage='standard_1020')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 4
#       2 tuh_sz.datasets[0].raw.get_montage()
#       3 mne.channels.get_builtin_montages()
# ----> 4 tuh_sz.datasets[0].raw.set_montage(montage='standard_1020')
#
# File <decorator-gen-35>:12, in set_montage(self, montage, match_case, match_alias, on_missing, verbose)
#
# File ~/anaconda3/envs/EEG_pipeline_V4/lib/python3.11/site-packages/mne/io/meas_info.py:424, in MontageMixin.set_montage(self, montage, match_case, match_alias, on_missing, verbose)
#     421 from ..channels.montage import _set_montage
#     423 info = self if isinstance(self, Info) else self.info
# --> 424 _set_montage(info, montage, match_case, match_alias, on_missing)
#     425 return self
#
# File ~/anaconda3/envs/EEG_pipeline_V4/lib/python3.11/site-packages/mne/channels/montage.py:1259, in _set_montage(***failed resolving arguments***)
# ...

# %%
tuh_sz.datasets[0].description['path']
# Out:
# '/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaexe/s001_2006_10_11/02_tcp_le/aaaaaexe_s001_t001.edf'

# %%
tuh_sz.datasets[1].raw.plot(start=470, duration=2)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
(tuh_sz.description)
# Out:
#     year  month  day                                               path  \
# 0   2006     10   11  /rds/general/user/nm2318/home/projects/scott_d...
# 1   2012     11    5  /rds/general/user/nm2318/home/projects/scott_d...
# 2   2012     11    5  /rds/general/user/nm2318/home/projects/scott_d...
# 3   2012     11    5  /rds/general/user/nm2318/home/projects/scott_d...
# 4   2012     11    5  /rds/general/user/nm2318/home/projects/scott_d...
# ..   ...    ...  ...                                                ...
# 95  2014      2    8  /rds/general/user/nm2318/home/projects/scott_d...
# 96  2014      2    8  /rds/general/user/nm2318/home/projects/scott_d...
# 97  2014      2    8  /rds/general/user/nm2318/home/projects/scott_d...
# 98  2014      2    8  /rds/general/user/nm2318/home/projects/scott_d...
# 99  2014      2   20  /rds/general/user/nm2318/home/projects/scott_d...
#
#    version   subject  session  segment  age gender  set channel_config
# ...

# %%
tuh_sz.datasets[0].raw
# Out:
# <RawEDF | aaaaaexe_s001_t001.edf, 41 x 356500 (1426.0 s), ~37 kB, data not loaded>

# %%
data, times = tuh_sz.datasets[0].raw[:, :] 
len(data[0])
# data is a tuple with the eeg signal, 41x356500
# Out:
# 356500

# %% [markdown]
# ## Extract the annotations from the csv and csvbi files

# %%
csvbi_file = open('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaoec/s002_2012_11_05/01_tcp_ar/aaaaaoec_s002_t004.csv_bi')
lines = csvbi_file.read()
print(lines)

# %%
csvbi_file = open('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaoec/s002_2012_11_05/01_tcp_ar/aaaaaoec_s002_t004.csv')
lines = csvbi_file.read()
print(lines)

# %%
csvbi_file_sz = open('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaajy/s001_2003_07_16/02_tcp_le/aaaaaajy_s001_t000.csv_bi')
lines = csvbi_file_sz.read()
print(lines)

# %%
csvbi_file_sz_v2 = open('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaajy/s001_2003_07_16/02_tcp_le/aaaaaajy_s001_t000.csv')
lines = csvbi_file_sz_v2.read()
print(lines)

# %%
import pandas as pd

file_path = '/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaajy/s001_2003_07_16/02_tcp_le/aaaaaajy_s001_t000.edf'
csv_path = file_path.replace('.edf', '.csv')
csv_bi_path = file_path.replace('.edf', '.csv_bi')

csv_file =  pd.read_csv(csv_path, header=5) # at the top of every file, there is a header that should not be read, example of header below
###########################################################
# version = csv_v1.0.0
# bname = aaaaaajy_s001_t000
# duration = 1750.00 secs
# montage_file = $NEDC_NFC/lib/nedc_eas_default_montage.txt
#
###########################################################
csvbi_file = pd.read_csv(csv_bi_path, header=5)

# %%
csv_file.drop([0], inplace=True)
csv_file
# Out:
#     channel  start_time  stop_time label  confidence
# 1     F7-T3     57.9964   196.0107  gnsz         1.0
# 2     T3-T5     57.9964   196.0107  gnsz         1.0
# 3     T3-T5    254.0130   362.9638  fnsz         1.0
# 4     T5-O1     57.9964   196.0107  gnsz         1.0
# 5     T5-O1    254.0130   362.9638  fnsz         1.0
# ..      ...         ...        ...   ...         ...
# 108   P4-O2    254.0130   362.9638  fnsz         1.0
# 109   P4-O2    477.0717   651.9384  fnsz         1.0
# 110   P4-O2    712.0451   908.0735  fnsz         1.0
# 111   P4-O2   1076.0047  1344.0545  fnsz         1.0
# 112   P4-O2   1380.0071  1687.9502  fnsz         1.0
#
# [112 rows x 5 columns]

# %%
csv_file.iloc[[0]]
# Out:
#   channel  start_time  stop_time label  confidence
# 1   F7-T3     57.9964   196.0107  gnsz         1.0

# %%
csv_file.loc[[108]]
# Out:
#     channel  start_time  stop_time label  confidence
# 108   P4-O2     254.013   362.9638  fnsz         1.0

# %%
#sanity check 
s = csv_file[['start_time','stop_time']].agg(frozenset, axis=1).value_counts()
s_df = pd.DataFrame(s)
s_df
# Out:
#                          0
# (57.9964, 196.0107)     22
# (362.9638, 254.013)     16
# (57.9846, 42.9994)      14
# (712.0451, 908.0735)    14
# (1344.0545, 1076.0047)  13
# (651.9384, 477.0717)    12
# (1380.0071, 1687.9502)  12
# (41.4938, 14.2442)       6
# (42.9816, 14.2442)       4

# %%
csv_file['duration'] =  csv_file.stop_time - csv_file.start_time
csv_file['description'] = csv_file.label + ',' + csv_file.confidence.astype(str) + ',' +  'EVENT'
csv_file = csv_file.sort_values(by = ['start_time', 'stop_time'], axis = 0) 
csv_file.reset_index(inplace=True, drop=True)

onsets = []
durations = []
descriptions = []
ch_names = []

while len(csv_file) > 0:
    print('len file: ', len(csv_file))
    temp_dataframe = pd.DataFrame()
    temp_dataframe = pd.concat([temp_dataframe, csv_file.iloc[[0]]], ignore_index=True)
    csv_file.drop([0], inplace=True)

    # get the values and check they match 
    start_time = str(temp_dataframe['start_time'][0])
    duration = str(temp_dataframe['duration'][0])
 
    #iterate through rows looking for identical start time and duration
    for index, row in csv_file.iterrows():        
        if( (str(row['start_time'])==start_time) and (str(row['duration'])==duration)   ):
            # if you have found a match, add it to the temporary dataframe and remove it from the csv_file dataframe 
            temp_dataframe = pd.concat([temp_dataframe, csv_file.loc[[index]]], ignore_index=True)
            csv_file.drop([index], inplace=True)
    
    print(temp_dataframe)
    print()
    
    onsets.append(temp_dataframe['start_time'][0]) 
    durations.append(temp_dataframe['duration'][0])
    descriptions.append(temp_dataframe['description'][0])
    ch_names.append(temp_dataframe['channel'].tolist())
    
    csv_file.reset_index(drop=True, inplace=True)
# Out:
# len file:  113
#   channel  start_time  stop_time label  confidence  duration     description
# 0   F8-T4     14.2442    41.4938  fnsz         1.0   27.2496  fnsz,1.0,EVENT
# 1   T4-T6     14.2442    41.4938  fnsz         1.0   27.2496  fnsz,1.0,EVENT
# 2   T6-O2     14.2442    41.4938  fnsz         1.0   27.2496  fnsz,1.0,EVENT
# 3   CZ-C4     14.2442    41.4938  fnsz         1.0   27.2496  fnsz,1.0,EVENT
# 4   C4-T4     14.2442    41.4938  fnsz         1.0   27.2496  fnsz,1.0,EVENT
# 5   T4-A2     14.2442    41.4938  fnsz         1.0   27.2496  fnsz,1.0,EVENT
#
# len file:  107
#   channel  start_time  stop_time label  confidence  duration     description
# 0  FP2-F4     14.2442    42.9816  fnsz         1.0   28.7374  fnsz,1.0,EVENT
# 1   F4-C4     14.2442    42.9816  fnsz         1.0   28.7374  fnsz,1.0,EVENT
# 2   C4-P4     14.2442    42.9816  fnsz         1.0   28.7374  fnsz,1.0,EVENT
# 3   P4-O2     14.2442    42.9816  fnsz         1.0   28.7374  fnsz,1.0,EVENT
#
# ...

# %%
ch_names
# Out:
# [['F8-T4', 'T4-T6', 'T6-O2', 'CZ-C4', 'C4-T4', 'T4-A2'],
#  ['FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2'],
#  ['FP2-F8',
#   'F8-T4',
#   'T4-T6',
#   'T6-O2',
#   'C3-CZ',
#   'CZ-C4',
#   'C4-T4',
#   'T4-A2',
#   'C3-P3',
#   'P3-O1',
#   'FP2-F4',
#   'F4-C4',
#   'C4-P4',
#   'P4-O2'],
#  ['FP1-F7',
#   'F7-T3',
#   'T3-T5',
#   'T5-O1',
#   'FP2-F8',
#   'F8-T4',
#   'T4-T6',
#   'T6-O2',
#   'A1-T3',
#   'T3-C3',
#   'C3-CZ',
#   'CZ-C4',
#   'C4-T4',
#   'T4-A2',
#   'FP1-F3',
#   'F3-C3',
#   'C3-P3',
#   'P3-O1',
#   'FP2-F4',
#   'F4-C4',
#   'C4-P4',
#   'P4-O2'],
#  ['T3-T5',
#   'T5-O1',
#   'F8-T4',
#   'T4-T6',
#   'T6-O2',
#   'T3-C3',
#   'C3-CZ',
#   'CZ-C4',
#   'C4-T4',
#   'T4-A2',
#   'F3-C3',
#   'C3-P3',
#   'P3-O1',
#   'F4-C4',
#   'C4-P4',
#   'P4-O2'],
#  ['F8-T4',
#   'T4-T6',
#   'T6-O2',
#   'T3-C3',
#   'C3-CZ',
#   'CZ-C4',
#   'C4-T4',
#   'T4-A2',
#   'FP2-F4',
#   'F4-C4',
#   'C4-P4',
#   'P4-O2'],
#  ['FP2-F8',
#   'F8-T4',
#   'T4-T6',
#   'T6-O2',
# ...

# %%
import mne
csvbi_annotations = mne.Annotations(onset = onsets, 
                                    duration = durations, 
                                    description = descriptions,
                                    ch_names=ch_names)

# %%
csvbi_annotations
# Out:
# <Annotations | 9 segments, channel-specific: fnsz,1.0,EVENT (8), ...>

# %%
sanity_check = csvbi_annotations.to_data_frame()
sanity_check
# Out:
#                        onset  duration     description  \
# 0 1970-01-01 00:00:14.244200   27.2496  fnsz,1.0,EVENT
# 1 1970-01-01 00:00:14.244200   28.7374  fnsz,1.0,EVENT
# 2 1970-01-01 00:00:42.999400   14.9852  fnsz,1.0,EVENT
# 3 1970-01-01 00:00:57.996400  138.0143  gnsz,1.0,EVENT
# 4 1970-01-01 00:04:14.013000  108.9508  fnsz,1.0,EVENT
# 5 1970-01-01 00:07:57.071700  174.8667  fnsz,1.0,EVENT
# 6 1970-01-01 00:11:52.045100  196.0284  fnsz,1.0,EVENT
# 7 1970-01-01 00:17:56.004700  268.0498  fnsz,1.0,EVENT
# 8 1970-01-01 00:23:00.007100  307.9431  fnsz,1.0,EVENT
#
#                                             ch_names
# 0         (F8-T4, T4-T6, T6-O2, CZ-C4, C4-T4, T4-A2)
# 1                      (FP2-F4, F4-C4, C4-P4, P4-O2)
# 2  (FP2-F8, F8-T4, T4-T6, T6-O2, C3-CZ, CZ-C4, C4...
# 3  (FP1-F7, F7-T3, T3-T5, T5-O1, FP2-F8, F8-T4, T...
# 4  (T3-T5, T5-O1, F8-T4, T4-T6, T6-O2, T3-C3, C3-...
# 5  (F8-T4, T4-T6, T6-O2, T3-C3, C3-CZ, CZ-C4, C4-...
# ...

# %% [markdown]
# ## Step 5: Try to make the create_from_raw_mne work
#
# the issue was that the initial function assumes that the raw objects have annotations, as it calls a creat_windows_from_events function, who segments the data according to events (extracted from annotations). I removed this, and used another function which creates evenly spaced windows.

# %%
import mne
import glob
import os

TUH_EEG_PATH = ('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0')

debug = True 
file_paths = glob.glob(os.path.join(TUH_EEG_PATH, '**/*.edf'), recursive=True)
# If debug is true and the number of edf files is bigger than 100, select 
# the first 100 file_paths
if (debug and len(file_paths)>100):
        file_paths = file_paths[0:100]

raw_tueeg_list = [mne.io.read_raw_edf(file_path) for file_path in file_paths]

# %%
raw_tueeg_list
# Out:
# [<RawEDF | aaaaaexe_s001_t001.edf, 41 x 356500 (1426.0 s), ~37 kB, data not loaded>,
#  <RawEDF | aaaaaoec_s002_t009.edf, 33 x 76800 (300.0 s), ~31 kB, data not loaded>,
#  <RawEDF | aaaaaoec_s002_t002.edf, 33 x 153856 (601.0 s), ~31 kB, data not loaded>,
#  <RawEDF | aaaaaoec_s002_t006.edf, 33 x 76800 (300.0 s), ~31 kB, data not loaded>,
#  <RawEDF | aaaaaoec_s002_t004.edf, 33 x 76800 (300.0 s), ~31 kB, data not loaded>,
#  <RawEDF | aaaaaoec_s002_t011.edf, 33 x 76800 (300.0 s), ~31 kB, data not loaded>,
#  <RawEDF | aaaaaoec_s002_t008.edf, 33 x 153856 (601.0 s), ~31 kB, data not loaded>,
#  <RawEDF | aaaaaoec_s002_t000.edf, 34 x 67584 (264.0 s), ~31 kB, data not loaded>,
#  <RawEDF | aaaaaoec_s002_t005.edf, 33 x 153856 (601.0 s), ~31 kB, data not loaded>,
#  <RawEDF | aaaaaoec_s002_t010.edf, 33 x 153856 (601.0 s), ~31 kB, data not loaded>,
#  <RawEDF | aaaaaoec_s002_t001.edf, 33 x 9216 (36.0 s), ~31 kB, data not loaded>,
# ...

# %%
from datasets.mne import create_from_mne_raw
tuh =  create_from_mne_raw(
    raw_tueeg_list,
    trial_start_offset_samples=0,
    trial_stop_offset_samples=None,
    window_size_samples=500,
    window_stride_samples=500,
    drop_last_window=False,
)

# %%
tuh.datasets[0].metadata
# Out:
#      i_window_in_trial  i_start_in_trial  i_stop_in_trial  target
# 0                    0                 0              500      -1
# 1                    1               500             1000      -1
# 2                    2              1000             1500      -1
# 3                    3              1500             2000      -1
# 4                    4              2000             2500      -1
# ..                 ...               ...              ...     ...
# 708                708            354000           354500      -1
# 709                709            354500           355000      -1
# 710                710            355000           355500      -1
# 711                711            355500           356000      -1
# 712                712            356000           356500      -1
#
# [713 rows x 4 columns]

# %% [markdown]
# ## Step 6: try to re-reference the raw samples to a bipolar montage on 1 sample
# This is important to load the channel information of the csv files associated with the TUSZ data

# %%
import mne
import glob
import os

TUH_EEG_PATH = ('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0')

debug = True 
file_paths = glob.glob(os.path.join(TUH_EEG_PATH, '**/*.edf'), recursive=True)
# If debug is true and the number of edf files is bigger than 100, select 
# the first 100 file_paths
if (debug and len(file_paths)>100):
        file_paths = file_paths[0:1]

raw_tueeg_list = [mne.io.read_raw_edf(file_path, preload=True) for file_path in file_paths]
# Out:
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaexe/s001_2006_10_11/02_tcp_le/aaaaaexe_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 356499  =      0.000 ...  1425.996 secs...

# %%
raw_tueeg_list[0].info['ch_names']
# Out:
# ['EEG FP1-LE',
#  'EEG FP2-LE',
#  'EEG F3-LE',
#  'EEG F4-LE',
#  'EEG C3-LE',
#  'EEG C4-LE',
#  'EEG A1-LE',
#  'EEG A2-LE',
#  'EEG P3-LE',
#  'EEG P4-LE',
#  'EEG O1-LE',
#  'EEG O2-LE',
#  'EEG F7-LE',
#  'EEG F8-LE',
#  'EEG T3-LE',
#  'EEG T4-LE',
#  'EEG T5-LE',
#  'EEG T6-LE',
#  'EEG FZ-LE',
#  'EEG CZ-LE',
#  'EEG PZ-LE',
#  'EEG OZ-LE',
#  'EEG PG1-LE',
#  'EEG PG2-LE',
#  'EEG EKG-LE',
#  'EEG 26-LE',
#  'EEG 27-LE',
#  'EEG 28-LE',
#  'EEG 29-LE',
#  'EEG 30-LE',
#  'EEG 31-LE',
#  'EEG 32-LE',
#  'PHOTIC PH',
#  'DC1-DC',
#  'DC2-DC',
#  'DC3-DC',
#  'DC4-DC',
#  'DC5-DC',
#  'DC6-DC',
#  'DC7-DC',
#  'DC8-DC']

# %%
raw_tueeg_list[0].plot(start=6, duration=6)
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
from datasets.montage_TUSZ import cathode_02, anode_02, bipolar_ch_names_02

copy_raw = raw_tueeg_list[0]
raw_re_ref = mne.set_bipolar_reference(copy_raw, anode=anode_02, cathode=cathode_02, ch_name=bipolar_ch_names_02)
# Out:
# EEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=22, n_times=356500
#     Range : 0 ... 356499 =      0.000 ...  1425.996 secs
# Ready.
# Added the following bipolar channels:
# FP1-F7, F7-T3, T3-T5, T5-O1, FP2-F8, F8-T4, T4-T6, T6-O2, A1-T3, T3-C3, C3-CZ, CZ-C4, C4-T4, T4-A2, FP1-F3, F3-C3, C3-P3, P3-O1, FP2-F4, F4-C4, C4-P4, P4-O2

# %%
ch_to_remove = [ch_name for ch_name in raw_re_ref.info['ch_names'] if (ch_name not in bipolar_ch_names_02) and (ch_name != 'EEG EKG-LE')]
raw_re_ref.drop_channels(ch_to_remove)
# Out:
# <RawEDF | aaaaaexe_s001_t001.edf, 23 x 356500 (1426.0 s), ~62.6 MB, data loaded>

# %%
raw_re_ref.plot(start=6, duration=16, n_channels=len(raw_re_ref.info['ch_names']))
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# ## Step 7: Figure out what the different montages are per corpus and their frequency
# only on TUSZ,TUAB an TUEG now, althought TUEG might be tricky

# %%
import os
import glob 

TUH_EEG = ('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg')
file_paths = glob.glob(os.path.join(TUH_EEG, '**/*.edf'), recursive=True)
montages = {}

debug = True
if (debug and len(file_paths)>50):
        file_paths = file_paths[0:5]
        
for file_path in file_paths:
        tokens = file_path.split(os.sep)
        if tokens[-2] not in montages.keys():
            montages[tokens[-2]] = 1
        else:
            montages[tokens[-2]] = montages[tokens[-2]] + 1

# %%
montages
# Out:
# {'02_tcp_le': 3, '01_tcp_ar': 2}

# %% [markdown]
# ## Step 8: Figure out what the different channel names are per corpus and their frequency
# only on TUSZ,TUAB an TUEG now, althought TUEG might be tricky
# UPDATE: This proves useful and was made into its own python script (see: https://github.com/ninamoutonnet/TUH_statistics)
# Needs to run on the cluster due to volume

# %%
import os
import glob 
import mne
import re

TUH_EEG = ('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_abnormal')
file_paths = glob.glob(os.path.join(TUH_EEG, '**/*.edf'), recursive=True)
channel_names = {}
age_dict = {}
sex_dict = {}

debug = True
if (debug and len(file_paths)>50):
        file_paths = file_paths[0:5]


for file_path in file_paths:
    
    # read EDF file
    raw = mne.io.read_raw_edf(file_path, preload=False, verbose='WARNING')
    for chname in raw.info['ch_names']:
        if chname not in channel_names.keys():
            channel_names[chname] = 1
        else: 
            channel_names[chname] = channel_names[chname] + 1
            
    # Read header file, extract age and sex from it
    f = open(file_path, "rb")
    header = f.read(88)
    f.close()
    # bytes 8 to 88 contain ascii local patient identification
    # see https://www.teuniz.net/edfbrowser/edf%20format%20description.html
    patient_id = header[8:].decode("ascii")
    
    # extract age
    found_age = re.findall(r"Age:(\d+)", patient_id)
    if len(found_age) == 1:
        age = int(found_age[0])
    # populate the age dictionnary
    if age not in age_dict.keys():
        age_dict[age] = 1
    else: 
        age_dict[age] = age_dict[age] + 1
    
    # extract gender  
    found_gender = re.findall(r"\s([F|M])\s", patient_id)
    if len(found_gender) == 1:
        gender = found_gender[0]
    # populate the age dictionnary
    if gender not in sex_dict.keys():
        sex_dict[gender] = 1
    else: 
        sex_dict[gender] = sex_dict[gender] + 1

# %%
channel_names
# Out:
# {'EEG FP1-REF': 5,
#  'EEG FP2-REF': 5,
#  'EEG F3-REF': 5,
#  'EEG F4-REF': 5,
#  'EEG C3-REF': 5,
#  'EEG C4-REF': 5,
#  'EEG P3-REF': 5,
#  'EEG P4-REF': 5,
#  'EEG O1-REF': 5,
#  'EEG O2-REF': 5,
#  'EEG F7-REF': 5,
#  'EEG F8-REF': 5,
#  'EEG T3-REF': 5,
#  'EEG T4-REF': 5,
#  'EEG T5-REF': 5,
#  'EEG T6-REF': 5,
#  'EEG A1-REF': 5,
#  'EEG A2-REF': 5,
#  'EEG FZ-REF': 5,
#  'EEG CZ-REF': 5,
#  'EEG PZ-REF': 5,
#  'EEG ROC-REF': 5,
#  'EEG LOC-REF': 5,
#  'EEG EKG1-REF': 5,
#  'EEG T1-REF': 5,
#  'EEG T2-REF': 5,
#  'PHOTIC-REF': 5,
#  'IBI': 5,
#  'BURSTS': 5,
#  'SUPPR': 5,
#  'EMG-REF': 3,
#  'EEG 26-REF': 3,
#  'EEG 27-REF': 3,
#  'EEG 28-REF': 3,
#  'EEG 29-REF': 3,
#  'EEG 30-REF': 3}

# %%
sex_dict
# Out:
# {'F': 5}

# %%
age_dict
# Out:
# {57: 2, 37: 1, 18: 1, 44: 1}

# %%
raw_tueeg_list[0].info
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: EEG FP1-REF, EEG FP2-REF, EEG F3-REF, EEG F4-REF, EEG C3-REF, ...
#  chs: 30 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: 2013-06-04 08:45:06 UTC
#  nchan: 30
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: 3 items (dict)
# >

# %%
import re

f = open(file_paths[0], "rb")
header = f.read(88)
f.close()
# bytes 8 to 88 contain ascii local patient identification
# see https://www.teuniz.net/edfbrowser/edf%20format%20description.html
patient_id = header[8:].decode("ascii")
age = -1
found_age = re.findall(r"Age:(\d+)", patient_id)
if len(found_age) == 1:
    age = int(found_age[0])
gender = "X"
found_gender = re.findall(r"\s([F|M])\s", patient_id)
if len(found_gender) == 1:
    gender = found_gender[0]

# %%
age
# Out:
# 57

# %%
gender
# Out:
# 'F'

# %% [markdown]
# ## Step 9: Remove meaningless channels from edf raws and re-reference the data according to the montage.
# See appendix of: https://isip.piconepress.com/publications/reports/2020/tuh_eeg/electrodes/

# %%
import os
import glob 
import mne
import re
from datasets.channel_clustering_TUH import unknown, DC_voltage, no_signal, custom_placement
from datasets.montage_TUSZ import cathode, anode, bipolar_ch_names 



TUH_EEG = ('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure')
file_paths = glob.glob(os.path.join(TUH_EEG, '**/*.edf'), recursive=True)
channels_to_remove = unknown + DC_voltage + no_signal + custom_placement

debug = True
#open 1 file if debug is true
if (debug and len(file_paths)>1):
        file_paths = file_paths[0:5]

for file_path in file_paths:
    
    # find the montage from the name of the file
    if '/01_tcp_ar/' in file_path: 
        index = 0
    elif '/02_tcp_le/' in file_path: 
        index = 1
    elif '/03_tcp_ar_a/' in file_path: 
        index = 2
    elif '/04_tcp_le_a/' in file_path: 
        index = 3
    
    sample_anode = anode[index]
    sample_cathode = cathode[index]
    sample_bipolar_ch_names = bipolar_ch_names[index]
    
    # read EDF file
    raw = mne.io.read_raw_edf(file_path, preload=True, verbose='WARNING')
    print(raw.info['ch_names'])
    # use the on_missing ignore tag as you can automatically try to remove channels 
    # and if they are not present, it will not raise an error
    raw = raw.drop_channels(ch_names = channels_to_remove, on_missing='ignore')  
    raw = mne.set_bipolar_reference(raw, anode=sample_anode, cathode=sample_cathode, ch_name=sample_bipolar_ch_names, verbose='WARNING')
    print(raw.info['ch_names'])
    #print()
# Out:
# ['EEG FP1-LE', 'EEG FP2-LE', 'EEG F3-LE', 'EEG F4-LE', 'EEG C3-LE', 'EEG C4-LE', 'EEG A1-LE', 'EEG A2-LE', 'EEG P3-LE', 'EEG P4-LE', 'EEG O1-LE', 'EEG O2-LE', 'EEG F7-LE', 'EEG F8-LE', 'EEG T3-LE', 'EEG T4-LE', 'EEG T5-LE', 'EEG T6-LE', 'EEG FZ-LE', 'EEG CZ-LE', 'EEG PZ-LE', 'EEG OZ-LE', 'EEG PG1-LE', 'EEG PG2-LE', 'EEG EKG-LE', 'EEG 26-LE', 'EEG 27-LE', 'EEG 28-LE', 'EEG 29-LE', 'EEG 30-LE', 'EEG 31-LE', 'EEG 32-LE', 'PHOTIC PH', 'DC1-DC', 'DC2-DC', 'DC3-DC', 'DC4-DC', 'DC5-DC', 'DC6-DC', 'DC7-DC', 'DC8-DC']
# ['EEG FZ-LE', 'EEG PZ-LE', 'EEG OZ-LE', 'EEG EKG-LE', 'PHOTIC PH', 'FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'A1-T3', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'T4-A2', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
#
# ...

# %% [markdown]
# ## Step 10: just like step 4, but try to add the csv info (channel dependent) on top of channel wide labels

# %%
TUH_SZ_PATH = ('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0')

# %%
from datasets.tuh import TUHSeizure
tuh_sz = TUHSeizure(path=TUH_SZ_PATH,    
    recording_ids= None,       
    target_name=None,    
    preload=True,    
    debug= True)
# Out:
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaexe/s001_2006_10_11/02_tcp_le/aaaaaexe_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 356499  =      0.000 ...  1425.996 secs...
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaoec/s001_2012_11_05/01_tcp_ar/aaaaaoec_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 406249  =      0.000 ...  1624.996 secs...
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaoec/s001_2012_11_05/01_tcp_ar/aaaaaoec_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15999  =      0.000 ...    63.996 secs...
# ...

# %%
tuh_sz.datasets[0].raw.annotations
# Out:
# <Annotations | 4 segments: seiz,1.0,TERM (4)>

# %%
tuh_sz.datasets[0].raw.info['ch_names']
# Out:
# ['EEG FP1-LE',
#  'EEG FP2-LE',
#  'EEG F3-LE',
#  'EEG F4-LE',
#  'EEG C3-LE',
#  'EEG C4-LE',
#  'EEG A1-LE',
#  'EEG A2-LE',
#  'EEG P3-LE',
#  'EEG P4-LE',
#  'EEG O1-LE',
#  'EEG O2-LE',
#  'EEG F7-LE',
#  'EEG F8-LE',
#  'EEG T3-LE',
#  'EEG T4-LE',
#  'EEG T5-LE',
#  'EEG T6-LE',
#  'EEG FZ-LE',
#  'EEG CZ-LE',
#  'EEG PZ-LE',
#  'EEG OZ-LE',
#  'EEG PG1-LE',
#  'EEG PG2-LE',
#  'EEG EKG-LE',
#  'EEG 26-LE',
#  'EEG 27-LE',
#  'EEG 28-LE',
#  'EEG 29-LE',
#  'EEG 30-LE',
#  'EEG 31-LE',
#  'EEG 32-LE',
#  'PHOTIC PH',
#  'DC1-DC',
#  'DC2-DC',
#  'DC3-DC',
#  'DC4-DC',
#  'DC5-DC',
#  'DC6-DC',
#  'DC7-DC',
#  'DC8-DC']

# %% [markdown]
# Add a parameter to the TUH class that will get rid of meaningless channels and another to set to a TCP bipolar montage

# %%
TUH_SZ_PATH = ('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0') 
from datasets.tuh import TUHSeizure
tuh_sz = TUHSeizure(path=TUH_SZ_PATH,    
    recording_ids= None,       
    target_name=None,    
    preload=True,    
    debug= True,
    remove_unknown_channels = False,
    set_bipolar_tcp = True)
# Out:
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaexe/s001_2006_10_11/02_tcp_le/aaaaaexe_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 356499  =      0.000 ...  1425.996 secs...
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaoec/s001_2012_11_05/01_tcp_ar/aaaaaoec_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 406249  =      0.000 ...  1624.996 secs...
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_seizure/v2.0.0/edf/dev/aaaaaoec/s001_2012_11_05/01_tcp_ar/aaaaaoec_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15999  =      0.000 ...    63.996 secs...
# ...

# %%
for i in range(len(tuh_sz.datasets[0].raw.annotations)):
    print(tuh_sz.datasets[0].raw.annotations[i])
    print()
# Out:
# OrderedDict([('onset', 193.844), ('duration', 6.200000000000017), ('description', 'seiz,1.0,TERM'), ('orig_time', datetime.datetime(2006, 10, 11, 14, 54, 2, tzinfo=datetime.timezone.utc)), ('ch_names', ())])
#
# OrderedDict([('onset', 193.844), ('duration', 6.200000000000017), ('description', 'absz,1.0,EVENT'), ('orig_time', datetime.datetime(2006, 10, 11, 14, 54, 2, tzinfo=datetime.timezone.utc)), ('ch_names', ('FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'A1-T3', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'T4-A2', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2'))])
#
# OrderedDict([('onset', 287.832), ('duration', 8.699999999999989), ('description', 'seiz,1.0,TERM'), ('orig_time', datetime.datetime(2006, 10, 11, 14, 54, 2, tzinfo=datetime.timezone.utc)), ('ch_names', ())])
#
# ...

# %%
tuh_sz.datasets[0].raw.info['ch_names']
# Out:
# ['EEG FZ-LE',
#  'EEG PZ-LE',
#  'EEG OZ-LE',
#  'EEG PG1-LE',
#  'EEG PG2-LE',
#  'EEG EKG-LE',
#  'EEG 26-LE',
#  'EEG 27-LE',
#  'EEG 28-LE',
#  'EEG 29-LE',
#  'EEG 30-LE',
#  'EEG 31-LE',
#  'EEG 32-LE',
#  'PHOTIC PH',
#  'DC1-DC',
#  'DC2-DC',
#  'DC3-DC',
#  'DC4-DC',
#  'DC5-DC',
#  'DC6-DC',
#  'DC7-DC',
#  'DC8-DC',
#  'FP1-F7',
#  'F7-T3',
#  'T3-T5',
#  'T5-O1',
#  'FP2-F8',
#  'F8-T4',
#  'T4-T6',
#  'T6-O2',
#  'A1-T3',
#  'T3-C3',
#  'C3-CZ',
#  'CZ-C4',
#  'C4-T4',
#  'T4-A2',
#  'FP1-F3',
#  'F3-C3',
#  'C3-P3',
#  'P3-O1',
#  'FP2-F4',
#  'F4-C4',
#  'C4-P4',
#  'P4-O2']

# %% [markdown]
# ### verify the emplementations work on all 3 sets: TUEG, TUAB, TUSZ

# %%
TUH_PATH = ('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg/v2.0.0') 
from datasets.tuh import TUH
tuh_eeg = TUH(path=TUH_PATH,    
    recording_ids= None,       
    target_name=None,    
    preload=True,    
    debug= True,
    remove_unknown_channels = False,
    set_bipolar_tcp = True)
# Out:
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg/v2.0.0/edf/068/aaaaakcf/s001_2009_12_23/01_tcp_ar/aaaaakcf_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 300749  =      0.000 ...  1202.996 secs...
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg/v2.0.0/edf/068/aaaaakel/s001_2010_05_18/01_tcp_ar/aaaaakel_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 302249  =      0.000 ...  1208.996 secs...
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg/v2.0.0/edf/068/aaaaakbr/s001_2010_07_21/01_tcp_ar/aaaaakbr_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 301749  =      0.000 ...  1206.996 secs...
# ...

# %%
tuh_eeg.datasets[0].raw.annotations
# Out:
# <Annotations | 0 segments>

# %%
tuh_eeg.datasets[0].raw.info['ch_names']
# Out:
# ['EEG FZ-REF',
#  'EEG PZ-REF',
#  'EEG ROC-REF',
#  'EEG LOC-REF',
#  'EEG EKG1-REF',
#  'EMG-REF',
#  'EEG 26-REF',
#  'EEG 27-REF',
#  'EEG 28-REF',
#  'EEG 29-REF',
#  'EEG 30-REF',
#  'EEG T1-REF',
#  'EEG T2-REF',
#  'PHOTIC-REF',
#  'IBI',
#  'BURSTS',
#  'SUPPR',
#  'FP1-F7',
#  'F7-T3',
#  'T3-T5',
#  'T5-O1',
#  'FP2-F8',
#  'F8-T4',
#  'T4-T6',
#  'T6-O2',
#  'A1-T3',
#  'T3-C3',
#  'C3-CZ',
#  'CZ-C4',
#  'C4-T4',
#  'T4-A2',
#  'FP1-F3',
#  'F3-C3',
#  'C3-P3',
#  'P3-O1',
#  'FP2-F4',
#  'F4-C4',
#  'C4-P4',
#  'P4-O2']

# %%
TUH_AB_PATH = ('/rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_abnormal/v3.0.0/') 
from datasets.tuh import TUHAbnormal
tuh_abnormal = TUHAbnormal(path=TUH_AB_PATH,    
    recording_ids= None,       
    target_name=None,    
    preload=True,    
    debug= True,
    remove_unknown_channels = True,
    set_bipolar_tcp = True)
# Out:
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_abnormal/v3.0.0/edf/train/abnormal/01_tcp_ar/aaaaambf_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 267007  =      0.000 ...  1042.996 secs...
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_abnormal/v3.0.0/edf/train/abnormal/01_tcp_ar/aaaaakgn_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 896749  =      0.000 ...  3586.996 secs...
# Extracting EDF parameters from /rds/general/user/nm2318/home/projects/scott_data_tuh/live/tuh_eeg_abnormal/v3.0.0/edf/train/abnormal/01_tcp_ar/aaaaakbz_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 360499  =      0.000 ...  1441.996 secs...
# ...

# %%
tuh_abnormal.datasets[0].raw.annotations
# Out:
# <Annotations | 0 segments>

# %%
tuh_abnormal.datasets[0].raw.info['ch_names']
# Out:
# ['EEG T1-REF',
#  'EEG T2-REF',
#  'EEG FZ-REF',
#  'EEG PZ-REF',
#  'EEG EKG1-REF',
#  'EEG SP1-REF',
#  'EEG SP2-REF',
#  'EMG-REF',
#  'IBI',
#  'FP1-F7',
#  'F7-T3',
#  'T3-T5',
#  'T5-O1',
#  'FP2-F8',
#  'F8-T4',
#  'T4-T6',
#  'T6-O2',
#  'A1-T3',
#  'T3-C3',
#  'C3-CZ',
#  'CZ-C4',
#  'C4-T4',
#  'T4-A2',
#  'FP1-F3',
#  'F3-C3',
#  'C3-P3',
#  'P3-O1',
#  'FP2-F4',
#  'F4-C4',
#  'C4-P4',
#  'P4-O2']
